# %%
import pandas as pd

# %%
import matplotlib.pyplot as py

# %%
import seaborn as sea

# %%
sns=pd.read_csv("C:/Users/navee/OneDrive/Desktop/market_fact.csv")

# %%
sns
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
py.hist(sns['Sales'])
py.show()

# %%
py.hist(sns['Sales'])
py.yscale('log')
py.show()

# %%
py.scatter(sns['Sales'],sns['Profit'])
py.show()

# %%
sea.distplot(sns['Shipping_Cost'])
py.show()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_12516\1107480106.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(sns['Shipping_Cost'])

# %%
sea.distplot(sns['Shipping_Cost'][:200], rug=True)
py.show()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_12516\1723571575.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(sns['Shipping_Cost'][:200], rug=True)

# %%
sea.distplot(sns['Sales'], hist=False)
py.show()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_12516\950938997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(sns['Sales'], hist=False)

# %%
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_12516\4182224443.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(sns['Sales'])
# C:\Users\navee\AppData\Local\Temp\ipykernel_12516\4182224443.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(sns['Profit'])
# ...

# %%
sea.boxplot(sns['Order_Quantity'])
py.title('Order_Quantity')
py.show()

# %%
sea.boxplot(x=sns['Order_Quantity'])
py.title('Order_Quantity')
py.show()

# %%
sea.jointplot(x='Sales',y= 'Profit', data=sns)
py.show()

# %%
sns =sns[(sns.Profit < 10000) & (sns.Sales < 20000)]

sea.jointplot(x='Sales',y='Profit',data= sns)
py.show()

# %%
sns =sns[(sns.Profit < 100) & (sns.Profit > -100) & (sns.Sales < 200)]
sea.jointplot(x='Sales',y='Profit',data=sns,kind="hex",color="b")
py.show()
